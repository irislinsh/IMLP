# %% [markdown]
# # Pandas數據分析
#
# 今天介紹資料分析近來很紅的 pandas 套件, 作者是 Wes McKinney。Python 會成為一個數據分析的熱門語言, 和 pandas 的出現也有相當的關係。
#
# 但是 pandas 雖然功能強, 但有些地方沒那麼直覺, 有時會讓大家以為是個深奧的套件。其實你大約可以把 pandas 想成「Python 的 Excel」, 但是功能更強、更有彈性、也有更多的可能性。
#
# 下面介紹個基本上就是把 pandas 當 Excel 學的影片, 相信大家會覺得很親切。<br>
# https://youtu.be/9d5-Ti6onew

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1 開始使用 `pandas`
#
# 首先我們來讀入一個 CSV 檔, 這裡有個「假的」學測成績, 叫 `grades.csv` 我們來練習一下。

# %%
df = pd.read_csv("data/grades.csv")

# %% [markdown]
# 用 `df` 是標準的叫法 (雖然這名稱我們隨便取也可以), 意思是 Data Frame, 這是 `pandas` 兩大資料結構之一。我們可以把 Data Frame 想成一張表格 (雖然其實可以是很多張表格)。
#
# 我們來看看我們 `df` 的前五筆資料。

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會
# 0  劉俊安   9  10  15  10  13
# 1  胡玉華  10  10  10   8   9
# 2  黃淑婷  13  15   8  11  14
# 3  陳上紫  10  10   8   9  14
# 4  崔靜成  13  12  14  12  13

# %% [markdown]
# 如果你曾經手動讀入 CSV 檔, 就知道這省了多少事 (雖然我個人還挺喜歡純手動帶進 CSV)。

# %% [markdown]
# #### Excel 檔也可以快速讀入
#
# 不只 CSV 檔, 很多資料檔案, 像 Excel 檔都很容易在 `pandas` 完成。使用法是這樣:
#
#     df2 = pd.read_excel('filename.xls', 'sheetname')
#
# 其中 sheetname 那裡要放工作表的名稱, 如果是中文的最好改成英文。

# %% [markdown]
# ## 2 Pandas 基本資料結構
#
# Pandas 有兩個基本資料結構:
#
# * <b style="color:red;">DataFrame</b>: 可以想成一個表格。
# * <b style="color:red;">Series</b>: 表格的某一列、某一行, 基本上就是我們以前的 list 或 array
#
# 一個 DataFrame, 我們有 `index` (列的名稱), `columns` (行的名稱)。
#
# #### DataFrame
#
# ![DataFrame 的結構](images/indexcol.png)

# %% [markdown]
# #### Series
#
# 剛剛說 series 大概就是一個 list, 一個 array。其實更精準的說, 其實是一個有 "index" 的 array。
#
# DataFrame 的每一行或每一列其實也都是一個 series。我們來看個例子, 例如所有同學的國文成績, 就是一個 series。

# %%
df['國文']
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# 在 Python 3 中, 我們終於可以和英文同步, 用這種很炫的方式叫出所有國文成績。

# %%
df.國文
# Out:
# 0      9
# 1     10
# 2     13
# 3     10
# 4     13
#       ..
# 95     9
# 96     8
# 97    14
# 98    15
# 99     9
# Name: 國文, Length: 100, dtype: int64

# %% [markdown]
# #### 資料畫出來
#
# 要畫個圖很容易。

# %%
df.國文.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# 當然, 在這個例子中, 其實畫 histogram 圖更有意義一點。

# %%
df.國文.hist(bins = 15)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## 3 一些基本的資料分析

# %% [markdown]
# 算平均。

# %%
df.國文.mean()
# Out:
# 11.39

# %% [markdown]
# 算標準差。

# %%
df.國文.std()
# Out:
# 2.1968526614594834

# %% [markdown]
# 不如就該算的都幫我們算算...

# %%
df.describe()
# Out:
#                國文          英文          數學         自然         社會
# count  100.000000  100.000000  100.000000  100.00000  100.00000
# mean    11.390000   11.380000   11.570000   11.03000   11.83000
# std      2.196853    2.273164    2.310516    2.21772    2.48655
# min      8.000000    8.000000    8.000000    8.00000    8.00000
# 25%      9.000000    9.000000   10.000000    9.00000    9.00000
# 50%     11.000000   11.000000   11.000000   11.00000   12.00000
# 75%     13.000000   13.000000   14.000000   13.00000   14.00000
# max     15.000000   15.000000   15.000000   15.00000   15.00000

# %% [markdown]
# 有時我們很愛看的相關係數矩陣。

# %%
df.corr()
# Out:
#           國文        英文        數學        自然        社會
# 國文  1.000000  0.160158 -0.310899 -0.110236 -0.028421
# 英文  0.160158  1.000000  0.025656  0.113929 -0.063512
# 數學 -0.310899  0.025656  1.000000  0.014371  0.041651
# 自然 -0.110236  0.113929  0.014371  1.000000 -0.156594
# 社會 -0.028421 -0.063512  0.041651 -0.156594  1.000000

# %% [markdown]
# 只算兩科間的相關係數當然也可以。

# %%
df.國文.corr(df.數學)
# Out:
# -0.3108989822179331

# %% [markdown]
# ## 4 增加一行

# %% [markdown]
# ### 【技巧】
#
# 我們增加一行, 加入總級分。

# %%
df["總級分"] = df.sum(axis = 1)
df.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分
# 0  劉俊安   9  10  15  10  13   57
# 1  胡玉華  10  10  10   8   9   47
# 2  黃淑婷  13  15   8  11  14   61
# 3  陳上紫  10  10   8   9  14   51
# 4  崔靜成  13  12  14  12  13   64

# %% [markdown]
# ### 【技巧】
#
# 有計算的當然也可以的。

# %%
df['加權'] = df.國文 + df.英文 + df.數學*2

# %%
df
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權
# 0   劉俊安   9  10  15  10  13   57  49
# 1   胡玉華  10  10  10   8   9   47  40
# 2   黃淑婷  13  15   8  11  14   61  44
# 3   陳上紫  10  10   8   9  14   51  36
# 4   崔靜成  13  12  14  12  13   64  53
# ..  ...  ..  ..  ..  ..  ..  ...  ..
# 95  蔡佳燕   9  10   9  13  14   55  37
# 96  吳筱婷   8  10  14  10  15   57  46
# 97  陳家銘  14   9  11   8  12   54  45
# 98  李明威  15   9   8   9  15   56  40
# 99  農揚勇   9  11  12  12  10   54  44
#
# [100 rows x 8 columns]

# %% [markdown]
# ## 5 排序和 index 重設

# %% [markdown]
# ### 【重點】排序的方法
#
# 我們依總級分來排序。

# %%
df.sort_values(by = '總級分', ascending = False).head(10)
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權
# 80  施雅鈴  13  15  12  13  13   66  52
# 12  李正偉  11  15  11  14  15   66  48
# 54  陳怡潔  15  15   9  15  11   65  48
# 25  蔡亦瑄  13  13  14  13  12   65  54
# 57  胡淳茜  12  15  14  13  11   65  55
# 37  曾怡君  11  12  15  13  14   65  53
# 48  陳怡婷  15  14  12   9  15   65  53
# 64  俞志峰   9  14  13  14  15   65  49
# 83  李士賢  10  14  15  13  13   65  54
# 87  趙偉希  10  13  14  13  15   65  51

# %% [markdown]
# ### 【重點】排序的方法
#
# 加權分最高, 同分才看總級分

# %%
df2 = df.sort_values(by = ['加權', '總級分'], ascending = False)

# %% [markdown]
# ### 【重點】重設 index

# %%
df2.index = range(1, 101)
df2.head()
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權
# 1  吳志遠  13  15  15   8   8   59  58
# 2  胡淳茜  12  15  14  13  11   65  55
# 3  詹威德  12  13  15  10  14   64  55
# 4  蔡亦瑄  13  13  14  13  12   65  54
# 5  李士賢  10  14  15  13  13   65  54

# %% [markdown]
# ## 6 篩出我們要的資料
#
# 基本上和 NumPy 的 array 篩法很像。

# %% [markdown]
# ### 【重點】
#
# 找出數學滿級分同學。

# %%
df2[df2.數學 == 15]
# Out:
#      姓名  國文  英文  數學  自然  社會  總級分  加權
# 1   吳志遠  13  15  15   8   8   59  58
# 3   詹威德  12  13  15  10  14   64  55
# 5   李士賢  10  14  15  13  13   65  54
# 7   曾怡君  11  12  15  13  14   65  53
# 10  林哲法  14   9  15  10  14   62  53
# 13  陳竹伯  10  12  15  10  14   61  52
# 15  葉儀依   9  13  15   8  14   59  52
# 18  周育霖   9  12  15  13  12   61  51
# 21  張雅彬  10  11  15  12   8   56  51
# 22  芮秋辛  11  10  15  10   8   54  51
# 25  胡勝傑   8  11  15  10  15   59  49
# 26  劉俊安   9  10  15  10  13   57  49
# 42  段冠廷   9   8  15  12  15   59  47

# %% [markdown]
# ### 【重點】
#
# 找出數學和英文都滿級分的同學。要注意 `and` 要用 `&`, `or` 要用 `|`。每個條件一定要加弧號。

# %%
df2[(df2.數學 == 15) & (df2.英文 == 15)]
# Out:
#     姓名  國文  英文  數學  自然  社會  總級分  加權
# 1  吳志遠  13  15  15   8   8   59  58

# %% [markdown]
# ## 7 刪除一行或一列

# %% [markdown]
# ### 【重點】刪掉一行
#
# 我們來刪掉總級分的那行。

# %%
df2.drop("總級分", axis = 1)
# Out:
#       姓名  國文  英文  數學  自然  社會  加權
# 1    吳志遠  13  15  15   8   8  58
# 2    胡淳茜  12  15  14  13  11  55
# 3    詹威德  12  13  15  10  14  55
# 4    蔡亦瑄  13  13  14  13  12  54
# 5    李士賢  10  14  15  13  13  54
# ..   ...  ..  ..  ..  ..  ..  ..
# 96   陳上紫  10  10   8   9  14  36
# 97   胡凱琳  10   8   9   9  15  36
# 98   林建亨   9  11   8   8  11  36
# 99   梁慧君   9   8   8   8  12  33
# 100  吳文伯   8   8   8  15  12  32
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 【重點】改變原有的 DataFrame
#
# 我們會發現 `pandas` 很多動作都沒有更改原有的 DataFrame, 真的要改要加入
#
#     inplace=True

# %%
df2.drop("總級分", axis = 1, inplace = True)
df2
# Out:
#       姓名  國文  英文  數學  自然  社會  加權
# 1    吳志遠  13  15  15   8   8  58
# 2    胡淳茜  12  15  14  13  11  55
# 3    詹威德  12  13  15  10  14  55
# 4    蔡亦瑄  13  13  14  13  12  54
# 5    李士賢  10  14  15  13  13  54
# ..   ...  ..  ..  ..  ..  ..  ..
# 96   陳上紫  10  10   8   9  14  36
# 97   胡凱琳  10   8   9   9  15  36
# 98   林建亨   9  11   8   8  11  36
# 99   梁慧君   9   8   8   8  12  33
# 100  吳文伯   8   8   8  15  12  32
#
# [100 rows x 7 columns]

# %% [markdown]
# ### 【重點】刪掉一列
#
# 刪掉列就是指定要刪去的 index。

# %%
df2.drop(5).head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權
# 1  吳志遠  13  15  15   8   8  58
# 2  胡淳茜  12  15  14  13  11  55
# 3  詹威德  12  13  15  10  14  55
# 4  蔡亦瑄  13  13  14  13  12  54
# 6  童心怡  13  13  14   8  13  54

# %%
df2.drop(df2[df2.姓名 == '李士賢'].index).head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權
# 1  吳志遠  13  15  15   8   8  58
# 2  胡淳茜  12  15  14  13  11  55
# 3  詹威德  12  13  15  10  14  55
# 4  蔡亦瑄  13  13  14  13  12  54
# 6  童心怡  13  13  14   8  13  54

# %% [markdown]
# ### 【重點】刪掉一列
#
# 通常刪掉符合條件的比較合理 (注意是找到要刪掉的部份, 再找出相對的 index)。

# %%
df2.drop(df2[df2.姓名 == '李士賢'].index).head()
# Out:
#     姓名  國文  英文  數學  自然  社會  加權
# 1  吳志遠  13  15  15   8   8  58
# 2  胡淳茜  12  15  14  13  11  55
# 3  詹威德  12  13  15  10  14  55
# 4  蔡亦瑄  13  13  14  13  12  54
# 6  童心怡  13  13  14   8  13  54

# %%
df2.drop(df2[df2.姓名 == '李士賢'].index, inplace = True)
df2
# Out:
#       姓名  國文  英文  數學  自然  社會  加權
# 1    吳志遠  13  15  15   8   8  58
# 2    胡淳茜  12  15  14  13  11  55
# 3    詹威德  12  13  15  10  14  55
# 4    蔡亦瑄  13  13  14  13  12  54
# 6    童心怡  13  13  14   8  13  54
# ..   ...  ..  ..  ..  ..  ..  ..
# 96   陳上紫  10  10   8   9  14  36
# 97   胡凱琳  10   8   9   9  15  36
# 98   林建亨   9  11   8   8  11  36
# 99   梁慧君   9   8   8   8  12  33
# 100  吳文伯   8   8   8  15  12  32
#
# [99 rows x 7 columns]

# %% [markdown]
# ## 8 真實股價資料
#
# 有個從 `Pandas` 獨立出來的套件叫 `pandas-datareader`, 幾經波折, 先是 Yahoo! 的財務資料不能用, 後來又是 Google 的資料不能用, 不過至少現在看來 Yahoo! 還可以使用。
#
# 安裝 `pandas-datareader` 就標準 `conda` 安裝:
#
#     conda install pandas-datareader
#
# 如果裝過, 但很久沒更新就用:
#
#     conda update pandas-datareader

# %% [markdown]
# ### 【例子】 分析 Apple 股價

# %%
import pandas_datareader as pdr
df = pdr.get_data_yahoo('AAPL')

# %%
# 為防止網路有問題, 我們把這個檔案以 aapl.csv 存起來, 可以這樣讀入。
# df = pd.read_csv('data/aapl.csv', index_col="Date")

# %%
df.head()
# Out:
#                  High        Low       Open      Close       Volume  Adj Close
# Date
# 2017-03-20  35.375000  35.057499  35.099998  35.365002   86168000.0  33.390224
# 2017-03-21  35.700001  34.932499  35.527500  34.959999  158119600.0  33.007828
# 2017-03-22  35.400002  34.939999  34.962502  35.355000  103440800.0  33.380775
# 2017-03-23  35.395000  35.152500  35.314999  35.230000   81385200.0  33.262745
# 2017-03-24  35.435001  35.087502  35.375000  35.160000   89582400.0  33.196663

# %% [markdown]
# #### 只要最後 300 個交易日!

# %%
df = df[-300:]
df
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2021-01-11  130.169998  128.500000  129.190002  128.979996  100384500.0
# 2021-01-12  129.690002  126.860001  128.500000  128.800003   91951100.0
# 2021-01-13  131.449997  128.490005  128.759995  130.889999   88636800.0
# 2021-01-14  131.000000  128.759995  130.800003  128.910004   90221800.0
# 2021-01-15  130.220001  127.000000  128.779999  127.139999  111598500.0
# ...                ...         ...         ...         ...          ...
# 2022-03-14  154.119995  150.100006  151.449997  150.619995  108732100.0
# 2022-03-15  155.570007  150.380005  150.899994  155.089996   92964300.0
# 2022-03-16  160.000000  154.460007  157.050003  159.589996  102300200.0
# 2022-03-17  161.000000  157.630005  158.610001  160.619995   75522800.0
# 2022-03-18  162.505005  159.759995  160.509995  162.199097   48318523.0
#
#              Adj Close
# Date
# 2021-01-11  128.026627
# 2021-01-12  127.847954
# 2021-01-13  129.922516
# 2021-01-14  127.957153
# 2021-01-15  126.200226
# ...                ...
# 2022-03-14  150.619995
# 2022-03-15  155.089996
# 2022-03-16  159.589996
# 2022-03-17  160.619995
# 2022-03-18  162.199097
#
# [300 rows x 6 columns]

# %% [markdown]
# #### 20 日的移動平均

# %%
df.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
df.Close.plot()
df.Close.rolling(20).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### 20 日和 60 日的移動平均

# %%
df.Close.plot(legend=True)
df.Close.rolling(20).mean().plot(label="$MA_{20}$",legend=True)
df.Close.rolling(60).mean().plot(label="$MA_{60}$",legend=True)
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### 準備做預測
#
# 我們用個非常天真的模型...
#
# ![天真股票模型](images/naive.png)
#
# 網路上說這是線性的 (可能嗎)!

# %%
close = df.Close.values
len(close)
# Out:
# 300

# %%
x = close[:-1]
x
# Out:
# array([128.97999573, 128.80000305, 130.88999939, 128.91000366,
#        127.13999939, 127.83000183, 132.02999878, 136.86999512,
#        139.07000732, 142.91999817, 143.16000366, 142.05999756,
#        137.08999634, 131.96000671, 134.13999939, 134.99000549,
#        133.94000244, 137.38999939, 136.75999451, 136.91000366,
#        136.00999451, 135.38999939, 135.13000488, 135.36999512,
#        133.19000244, 130.83999634, 129.71000671, 129.86999512,
#        126.        , 125.86000061, 125.34999847, 120.98999786,
#        121.26000214, 127.79000092, 125.12000275, 122.05999756,
#        120.12999725, 121.41999817, 116.36000061, 121.08999634,
#        119.98000336, 121.95999908, 121.02999878, 123.98999786,
#        125.56999969, 124.76000214, 120.52999878, 119.98999786,
#        123.38999939, 122.54000092, 120.08999634, 120.58999634,
#        121.20999908, 121.38999939, 119.90000153, 122.15000153,
#        123.        , 125.90000153, 126.20999908, 127.90000153,
#        130.36000061, 133.        , 131.24000549, 134.42999268,
#        132.02999878, 134.5       , 134.16000366, 134.83999634,
#        133.11000061, 133.5       , 131.94000244, 134.32000732,
#        134.72000122, 134.38999939, 133.58000183, 133.47999573,
#        131.46000671, 132.53999329, 127.84999847, 128.1000061 ,
#        129.74000549, 130.21000671, 126.84999847, 125.91000366,
#        122.76999664, 124.97000122, 127.44999695, 126.26999664,
#        124.84999847, 124.69000244, 127.30999756, 125.43000031,
#        127.09999847, 126.90000153, 126.84999847, 125.27999878,
#        124.61000061, 124.27999878, 125.05999756, 123.54000092,
#        125.88999939, 125.90000153, 126.73999786, 127.12999725,
#        126.11000061, 127.34999847, 130.47999573, 129.63999939,
#        130.1499939 , 131.78999329, 130.46000671, 132.30000305,
#        133.97999573, 133.69999695, 133.41000366, 133.11000061,
#        134.77999878, 136.33000183, 136.96000671, 137.27000427,
#        139.96000671, 142.02000427, 144.57000732, 143.24000549,
#        145.11000061, 144.5       , 145.63999939, 149.1499939 ,
#        148.47999573, 146.38999939, 142.44999695, 146.1499939 ,
#        145.3999939 , 146.80000305, 148.55999756, 148.99000549,
#        146.77000427, 144.97999573, 145.63999939, 145.86000061,
#        145.52000427, 147.36000061, 146.94999695, 147.05999756,
#        146.13999939, 146.08999634, 145.6000061 , 145.86000061,
#        148.88999939, 149.1000061 , 151.11999512, 150.19000244,
#        146.36000061, 146.69999695, 148.19000244, 149.71000671,
#        149.61999512, 148.36000061, 147.53999329, 148.6000061 ,
#        153.11999512, 151.83000183, 152.50999451, 153.6499939 ,
#        154.30000305, 156.69000244, 155.11000061, 154.07000732,
#        148.97000122, 149.55000305, 148.11999512, 149.02999878,
#        148.78999329, 146.05999756, 142.94000244, 143.42999268,
#        145.8500061 , 146.83000183, 146.91999817, 145.36999512,
#        141.91000366, 142.83000183, 141.5       , 142.6499939 ,
#        139.13999939, 141.11000061, 142.        , 143.28999329,
#        142.8999939 , 142.80999756, 141.50999451, 140.91000366,
#        143.75999451, 144.83999634, 146.55000305, 148.75999451,
#        149.25999451, 149.47999573, 148.69000244, 148.63999939,
#        149.32000732, 148.8500061 , 152.57000732, 149.80000305,
#        148.96000671, 150.02000427, 151.49000549, 150.96000671,
#        151.27999878, 150.44000244, 150.80999756, 147.91999817,
#        147.86999512, 149.99000549, 150.        , 151.        ,
#        153.49000549, 157.86999512, 160.55000305, 161.02000427,
#        161.41000366, 161.94000244, 156.80999756, 160.24000549,
#        165.30000305, 164.77000427, 163.75999451, 161.83999634,
#        165.32000732, 171.17999268, 175.08000183, 174.55999756,
#        179.44999695, 175.74000549, 174.33000183, 179.30000305,
#        172.25999451, 171.13999939, 169.75      , 172.99000549,
#        175.63999939, 176.27999878, 180.33000183, 179.28999329,
#        179.38000488, 178.19999695, 177.57000732, 182.00999451,
#        179.69999695, 174.91999817, 172.        , 172.16999817,
#        172.19000244, 175.08000183, 175.52999878, 172.19000244,
#        173.07000732, 169.80000305, 166.22999573, 164.50999451,
#        162.41000366, 161.61999512, 159.77999878, 159.69000244,
#        159.22000122, 170.33000183, 174.77999878, 174.61000061,
#        175.83999634, 172.8999939 , 172.38999939, 171.66000366,
#        174.83000183, 176.27999878, 172.11999512, 168.63999939,
#        168.88000488, 172.78999329, 172.55000305, 168.88000488,
#        167.30000305, 164.32000732, 160.07000732, 162.74000549,
#        164.8500061 , 165.11999512, 163.19999695, 166.55999756,
#        166.22999573, 163.16999817, 159.30000305, 157.44000244,
#        162.94999695, 158.52000427, 154.72999573, 150.61999512,
#        155.08999634, 159.58999634, 160.61999512])

# %%
y = close[1:]
len(y)
# Out:
# 299

# %%
plt.scatter(x, y)

# %% [markdown]
# 哦, 真的有點像線性的, 我們之後用線性迴歸試試看。

# %% [markdown]
# ## 9 手工打造一個 DataFrame*
#
# 有時我們用手工打造一個簡單的 DataFrame, 可以更理解整個結構。其實很容易, 一個 DataFrame 基本上就包含兩個主要部份:
#
# * 資料本身: 通常一個二維陣列 (矩陣)
# * 行、列的名稱
#
# 我們來個簡單的小例子。

# %%
mydata = np.random.randn(4,3)

# %%
mydata
# Out:
# array([[-0.04213434,  0.50973126,  0.84745978],
#        [-0.88361996,  3.03822719, -0.83322001],
#        [ 1.05859151, -1.06054025,  1.19915579],
#        [ 0.41268773, -1.37031096, -1.04612163]])

# %% [markdown]
# 把行列的名字放進去, 就成一個 DataFrame。我們列的部份先讓 Python 自己產生。

# %%
df2 = pd.DataFrame(mydata, columns = list("ABC"))

# %%
df2
# Out:
#           A         B         C
# 0 -0.042134  0.509731  0.847460
# 1 -0.883620  3.038227 -0.833220
# 2  1.058592 -1.060540  1.199156
# 3  0.412688 -1.370311 -1.046122

# %% [markdown]
# #### 兩個表格上下貼起來
#
# 我們再來生一個 DataFrame, 再「貼」起來。

# %%
df3 = pd.DataFrame(np.random.randn(3,3), columns = list("ABC"))

# %%
df3
# Out:
#           A         B         C
# 0 -0.261976  0.224877 -0.388332
# 1  0.351802  0.361144  0.427701
# 2  0.057939  1.744505  0.424751

# %%
df4 = pd.concat([df2, df3], axis = 0)

# %%
df4
# Out:
#           A         B         C
# 0 -0.042134  0.509731  0.847460
# 1 -0.883620  3.038227 -0.833220
# 2  1.058592 -1.060540  1.199156
# 3  0.412688 -1.370311 -1.046122
# 0 -0.261976  0.224877 -0.388332
# 1  0.351802  0.361144  0.427701
# 2  0.057939  1.744505  0.424751

# %% [markdown]
# 前面我們弄得亂七八糟的 index 重設一下。

# %%
df4.index = range(len(df4))

# %%
df4
# Out:
#           A         B         C
# 0 -0.042134  0.509731  0.847460
# 1 -0.883620  3.038227 -0.833220
# 2  1.058592 -1.060540  1.199156
# 3  0.412688 -1.370311 -1.046122
# 4 -0.261976  0.224877 -0.388332
# 5  0.351802  0.361144  0.427701
# 6  0.057939  1.744505  0.424751

# %% [markdown]
# #### 横向的貼

# %%
df5 = pd.concat([df2, df3], axis = 1)

# %% [markdown]
# 等等, 這大小好像不太對也可以嗎? 答案是可以的!

# %%
df5
# Out:
#           A         B         C         A         B         C
# 0 -0.042134  0.509731  0.847460 -0.261976  0.224877 -0.388332
# 1 -0.883620  3.038227 -0.833220  0.351802  0.361144  0.427701
# 2  1.058592 -1.060540  1.199156  0.057939  1.744505  0.424751
# 3  0.412688 -1.370311 -1.046122       NaN       NaN       NaN

# %% [markdown]
# #### 大一點的例子
#
# 我們來做前面「假的」學測資料。首先要有「假的」同學名單, 如果有興趣產生很多名字, 可以用這個服務。
#
# [中文姓名產生器](http://www.richyli.com/name/index.asp)

# %%
df_names = pd.read_csv('data/names.csv', names = ['姓名'])

# %%
df_names.head()
# Out:
#     姓名
# 0  羅雅慧
# 1  王紹尹
# 2  黃季坤
# 3  許正書
# 4  張鈞蓮

# %%
df_grades = pd.DataFrame(np.random.randint(6,16,(100,5)), columns = ['國文','英文','數學','社會','自然'])

# %%
df_grades
# Out:
#     國文  英文  數學  社會  自然
# 0   11   9  15   7  13
# 1   15  14   7   8   8
# 2   14   8  10   9  14
# 3   11   8   8  12  13
# 4    8  15  11  12  11
# ..  ..  ..  ..  ..  ..
# 95  15  13  13  10   8
# 96  12  15   7   8  11
# 97   9   6   9   9  10
# 98  13  10  11  10  12
# 99   6  15  10  15   9
#
# [100 rows x 5 columns]

# %%
df_grades.to_csv('data/gradeEd.csv')

# %%
df6 = pd.read_csv('data/gradeEd.csv')
df6.head()
# Out:
#    Unnamed: 0  國文  英文  數學  社會  自然
# 0           0  11   9  15   7  13
# 1           1  15  14   7   8   8
# 2           2  14   8  10   9  14
# 3           3  11   8   8  12  13
# 4           4   8  15  11  12  11

# %%
df_x = pd.concat([df_names, df_grades], axis = 1)

# %%
df_x
# Out:
#      姓名  國文  英文  數學  社會  自然
# 0   羅雅慧  11   9  15   7  13
# 1   王紹尹  15  14   7   8   8
# 2   黃季坤  14   8  10   9  14
# 3   許正書  11   8   8  12  13
# 4   張鈞蓮   8  15  11  12  11
# ..  ...  ..  ..  ..  ..  ..
# 95  陳君生  15  13  13  10   8
# 96  曾桂甫  12  15   7   8  11
# 97  林欣怡   9   6   9   9  10
# 98  林佳霖  13  10  11  10  12
# 99  胡筱芸   6  15  10  15   9
#
# [100 rows x 6 columns]
